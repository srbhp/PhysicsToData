# %%
import pandas as pd

# %%
df = pd.read_csv("dataIMR1971-2012_2.csv")
df.sample(5)
# Out:
#    Category Country/ State/ UT Name  Infant mortality rate - 1971  \
# 21    State       Jammu and Kashmir                           NaN
# 27    State                 Tripura                           NaN
# 15    State              Tamil Nadu                         113.0
# 2     State                   Assam                         139.0
# 5     State                 Gujarat                         144.0
#
#     Infant mortality rate - 1972  Infant mortality rate - 1973  \
# 21                           NaN                          65.0
# 27                           NaN                           NaN
# 15                         121.0                         108.0
# 2                          136.0                         136.0
# 5                          128.0                         161.0
#
#     Infant mortality rate - 1974  Infant mortality rate - 1975  \
# 21                          76.0                          68.0
# ...

# %%
df = df.T

# %%
df = df.drop(['Category'])

# %%
df.index
# Out:
# Index(['Country/ State/ UT Name', 'Infant mortality rate - 1971',
#        'Infant mortality rate - 1972', 'Infant mortality rate - 1973',
#        'Infant mortality rate - 1974', 'Infant mortality rate - 1975',
#        'Infant mortality rate - 1976', 'Infant mortality rate - 1977',
#        'Infant mortality rate - 1978', 'Infant mortality rate - 1979',
#        'Infant mortality rate - 1980', 'Infant mortality rate - 1981',
#        'Infant mortality rate - 1982', 'Infant mortality rate - 1983',
#        'Infant mortality rate - 1984', 'Infant mortality rate - 1985',
#        'Infant mortality rate - 1986', 'Infant mortality rate - 1987',
#        'Infant mortality rate - 1988', 'Infant mortality rate - 1989',
#        'Infant mortality rate - 1990', 'Infant mortality rate - 1991',
#        'Infant mortality rate - 1992', 'Infant mortality rate - 1993',
#        'Infant mortality rate - 1994', 'Infant mortality rate - 1995',
# ...

# %%
df.index = df.index.map(lambda x : x[-4:])

# %%
df.columns  = df.columns = df.iloc[0]

# %%
df = df.drop(['Name'])

# %%
df.plot()
import matplotlib.pylab as plt 
plt.legend(ncols = 5)

# %%
df.iloc[0][df.iloc[0].notna()]
# Out:
# Name
# India (Average)    129.0
# Andhra Pradesh     106.0
# Assam              139.0
# Gujarat            144.0
# Haryana             72.0
# Karnataka           95.0
# Kerala              58.0
# Madhya Pradesh     135.0
# Maharashtra        105.0
# Odisha             127.0
# Punjab             102.0
# Tamil Nadu         113.0
# Uttar Pradesh      167.0
# Name: 1971, dtype: object
